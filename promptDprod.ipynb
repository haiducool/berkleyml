# %% [markdown]
# ### Will a Customer Accept the Coupon?
#
# **Context**
#
# Imagine driving through town and a coupon is delivered to your cell phone for a restaraunt near where you are driving. Would you accept that coupon and take a short detour to the restaraunt? Would you accept the coupon but use it on a sunbsequent trip? Would you ignore the coupon entirely? What if the coupon was for a bar instead of a restaraunt? What about a coffee house? Would you accept a bar coupon with a minor passenger in the car? What about if it was just you and your partner in the car? Would weather impact the rate of acceptance? What about the time of day?
#
# Obviously, proximity to the business is a factor on whether the coupon is delivered to the driver or not, but what are the factors that determine whether a driver accepts the coupon once it is delivered to them? How would you determine whether a driver is likely to accept a coupon?
#
# **Overview**
#
# The goal of this project is to use what you know about visualizations and probability distributions to distinguish between customers who accepted a driving coupon versus those that did not.
#
# **Data**
#
# This data comes to us from the UCI Machine Learning repository and was collected via a survey on Amazon Mechanical Turk. The survey describes different driving scenarios including the destination, current time, weather, passenger, etc., and then ask the person whether he will accept the coupon if he is the driver. Answers that the user will drive there ‘right away’ or ‘later before the coupon expires’ are labeled as ‘Y = 1’ and answers ‘no, I do not want the coupon’ are labeled as ‘Y = 0’.  There are five different types of coupons -- less expensive restaurants (under \\$20), coffee houses, carry out & take away, bar, and more expensive restaurants (\\$20 - \\$50).

# %% [markdown]
# **Deliverables**
#
# Your final product should be a brief report that highlights the differences between customers who did and did not accept the coupons.  To explore the data you will utilize your knowledge of plotting, statistical summaries, and visualization using Python. You will publish your findings in a public facing github repository as your first portfolio piece.

# %% [markdown]
# ### Data Description
#
# The attributes of this data set include:
# 1. User attributes
#     -  Gender: male, female
#     -  Age: below 21, 21 to 25, 26 to 30, etc.
#     -  Marital Status: single, married partner, unmarried partner, or widowed
#     -  Number of children: 0, 1, or more than 1
#     -  Education: high school, bachelors degree, associates degree, or graduate degree
#     -  Occupation: architecture & engineering, business & financial, etc.
#     -  Annual income: less than \\$12500, \\$12500 - \\$24999, \\$25000 - \\$37499, etc.
#     -  Number of times that he/she goes to a bar: 0, less than 1, 1 to 3, 4 to 8 or greater than 8
#     -  Number of times that he/she buys takeaway food: 0, less than 1, 1 to 3, 4 to 8 or greater
#     than 8
#     -  Number of times that he/she goes to a coffee house: 0, less than 1, 1 to 3, 4 to 8 or
#     greater than 8
#     -  Number of times that he/she eats at a restaurant with average expense less than \\$20 per
#     person: 0, less than 1, 1 to 3, 4 to 8 or greater than 8
#     -  Number of times that he/she goes to a bar: 0, less than 1, 1 to 3, 4 to 8 or greater than 8
#
#
# 2. Contextual attributes
#     - Driving destination: home, work, or no urgent destination
#     - Location of user, coupon and destination: we provide a map to show the geographical
#     location of the user, destination, and the venue, and we mark the distance between each
#     two places with time of driving. The user can see whether the venue is in the same
#     direction as the destination.
#     - Weather: sunny, rainy, or snowy
#     - Temperature: 30F, 55F, or 80F
#     - Time: 10AM, 2PM, or 6PM
#     - Passenger: alone, partner, kid(s), or friend(s)
#
#
# 3. Coupon attributes
#     - time before it expires: 2 hours or one day

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %% [markdown]
# ### Problems
#
# Use the prompts below to get started with your data analysis.
#
# 1. Read in the `coupons.csv` file.

# %%
#For efficiency and flexibility, I am using my work laptop where Jupiter is not allowed, therefore am using Google Colab Pro.
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data = pd.read_csv('drive/MyDrive/Colab Notebooks/Module5/assignment_5_1_starter/data/coupons.csv')

# %%
data.head()
# Out:
#        destination  passanger weather  temperature  time  \
# 0  No Urgent Place      Alone   Sunny           55   2PM
# 1  No Urgent Place  Friend(s)   Sunny           80  10AM
# 2  No Urgent Place  Friend(s)   Sunny           80  10AM
# 3  No Urgent Place  Friend(s)   Sunny           80   2PM
# 4  No Urgent Place  Friend(s)   Sunny           80   2PM
#
#                   coupon expiration  gender age      maritalStatus  ...  \
# 0        Restaurant(<20)         1d  Female  21  Unmarried partner  ...
# 1           Coffee House         2h  Female  21  Unmarried partner  ...
# 2  Carry out & Take away         2h  Female  21  Unmarried partner  ...
# 3           Coffee House         2h  Female  21  Unmarried partner  ...
# 4           Coffee House         1d  Female  21  Unmarried partner  ...
#
#    CoffeeHouse CarryAway RestaurantLessThan20 Restaurant20To50  \
# 0        never       NaN                  4~8              1~3
# 1        never       NaN                  4~8              1~3
# 2        never       NaN                  4~8              1~3
# 3        never       NaN                  4~8              1~3
# 4        never       NaN                  4~8              1~3
#
#   toCoupon_GEQ5min toCoupon_GEQ15min toCoupon_GEQ25min direction_same  \
# 0                1                 0                 0              0
# 1                1                 0                 0              0
# 2                1                 1                 0              0
# 3                1                 1                 0              0
# 4                1                 1                 0              0
#
#   direction_opp  Y
# 0             1  1
# 1             1  0
# 2             1  1
# 3             1  0
# 4             1  0
#
# [5 rows x 26 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12684 entries, 0 to 12683
# Data columns (total 26 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   destination           12684 non-null  object
#  1   passanger             12684 non-null  object
#  2   weather               12684 non-null  object
#  3   temperature           12684 non-null  int64
#  4   time                  12684 non-null  object
#  5   coupon                12684 non-null  object
#  6   expiration            12684 non-null  object
#  7   gender                12684 non-null  object
#  8   age                   12684 non-null  object
#  9   maritalStatus         12684 non-null  object
#  10  has_children          12684 non-null  int64
#  11  education             12684 non-null  object
#  12  occupation            12684 non-null  object
#  13  income                12684 non-null  object
#  14  car                   108 non-null    object
#  15  Bar                   12577 non-null  object
#  16  CoffeeHouse           12467 non-null  object
#  17  CarryAway             12533 non-null  object
#  18  RestaurantLessThan20  12554 non-null  object
#  19  Restaurant20To50      12495 non-null  object
#  20  toCoupon_GEQ5min      12684 non-null  int64
#  21  toCoupon_GEQ15min     12684 non-null  int64
#  22  toCoupon_GEQ25min     12684 non-null  int64
#  23  direction_same        12684 non-null  int64
#  24  direction_opp         12684 non-null  int64
#  25  Y                     12684 non-null  int64
# dtypes: int64(8), object(18)
# memory usage: 2.5+ MB

# %% [markdown]
# 2. Investigate the dataset for missing or problematic data.

# %%
# Create a subset with only categorical columns
categoric = data.select_dtypes('object').columns
# Plot histograms for each categorical column
plt.figure(figsize=(15,80))
for i, col in enumerate(categoric):
    ax = plt.subplot(len(categoric), 1, i+1)
    sns.histplot(data=data, x=col, ax=ax)

# %%
# Here I would like examine numerical fields in the dataset 
# Create a subset of dataframe that includes only numerical columns:
numerical = data.select_dtypes('int64').columns
# Plot histograms of each numerical column:
plt.figure(figsize=(20,4))
for i, col in enumerate(numerical):
    ax = plt.subplot(1, len(numerical), i+1)
    sns.histplot(data=data, x=col, ax=ax)

# %%
### Determine which columns have null values: 
missing_vals = data.isnull().sum()
missing_vals
# Out:
# destination                 0
# passanger                   0
# weather                     0
# temperature                 0
# time                        0
# coupon                      0
# expiration                  0
# gender                      0
# age                         0
# maritalStatus               0
# has_children                0
# education                   0
# occupation                  0
# income                      0
# car                     12576
# Bar                       107
# CoffeeHouse               217
# CarryAway                 151
# RestaurantLessThan20      130
# Restaurant20To50          189
# toCoupon_GEQ5min            0
# toCoupon_GEQ15min           0
# toCoupon_GEQ25min           0
# direction_same              0
# direction_opp               0
# Y                           0
# dtype: int64

# %% [markdown]
# 3. Decide what to do about your missing data -- drop, replace, other...

# %%
## looks like 'car' column is missing most values - remove the column
## rest of columns with missing data - is ~1% of data each, explore removing that as well. 
data.shape
# Out:
# (12684, 26)

# %%
# remove column car
data1 = data.drop(columns=['car'])
missing_vals = data1.isnull().sum()
missing_vals
# Out:
# destination               0
# passanger                 0
# weather                   0
# temperature               0
# time                      0
# coupon                    0
# expiration                0
# gender                    0
# age                       0
# maritalStatus             0
# has_children              0
# education                 0
# occupation                0
# income                    0
# Bar                     107
# CoffeeHouse             217
# CarryAway               151
# RestaurantLessThan20    130
# Restaurant20To50        189
# toCoupon_GEQ5min          0
# toCoupon_GEQ15min         0
# toCoupon_GEQ25min         0
# direction_same            0
# direction_opp             0
# Y                         0
# dtype: int64

# %%
## filter out all rows with nulls() and verify the output
data2 = data1.dropna()
#data2.shape
data2.isnull().sum()
# Out:
# destination             0
# passanger               0
# weather                 0
# temperature             0
# time                    0
# coupon                  0
# expiration              0
# gender                  0
# age                     0
# maritalStatus           0
# has_children            0
# education               0
# occupation              0
# income                  0
# Bar                     0
# CoffeeHouse             0
# CarryAway               0
# RestaurantLessThan20    0
# Restaurant20To50        0
# toCoupon_GEQ5min        0
# toCoupon_GEQ15min       0
# toCoupon_GEQ25min       0
# direction_same          0
# direction_opp           0
# Y                       0
# dtype: int64

# %%
# 1. Plot multiple charts to understand the distribution for each category between accepting and not
# First filter for only categorical columns
categoric = data2.select_dtypes('object').columns
# Then create individual countplots for each categorical column, this time including a breakdown between Y/N.
plt.figure(figsize=(18, 100))
for i, col in enumerate(categoric):
   ax = plt.subplot(len(categoric), 1, i+1)
   sns.countplot(data=data2, x=col, ax=ax, hue = 'Y')

# %% [markdown]
# 4. What proportion of the total observations chose to accept the coupon?

# %%
data2.loc[data2['Y'] == 1].shape[0]/ data2.shape[0]
# Out:
# 0.5693352098683666

# %% [markdown]
# 5. Use a bar plot to visualize the `coupon` column.

# %%
sns.barplot(y="coupon", x="Y", data=data2)

# %%
# Lets also explore acceptance rate based 
x,y = 'coupon', 'Y' 

qchart = data2.groupby(x)[y].value_counts(normalize=True).mul(100).round(0).rename('percent').reset_index()
g = sns.catplot(x=x,y='percent',hue=y,kind='bar',data=qchart,  height=4, aspect=2.5)
g.fig.suptitle(' Acceptance based on coupon type', size = 10)
g.ax.set_ylim(0,100)


for p in g.ax.patches:
    txt = str(p.get_height().round(2)) + '%'
    txt_x = p.get_x() 
    txt_y = p.get_height()
    g.ax.text(txt_x,txt_y,txt)

#Takewaway: Acceptance rate varies greatly by coupon type, lowest is Bar, and highest is Carry out & Take away

# %% [markdown]
# 6. Use a histogram to visualize the temperature column.

# %%
sns.histplot(data=data2, x = 'temperature')

# %% [markdown]
# **Investigating the Bar Coupons**
#
# Now, we will lead you through an exploration of just the bar related coupons.
#
# 1. Create a new `DataFrame` that contains just the bar coupons.

# %%
bar_coupons = data2.loc[data2['coupon'] == 'Bar'].copy()
#bar_coupons.shape[0]

# %% [markdown]
# 2. What proportion of bar coupons were accepted?

# %%
bar_coupons.loc[bar_coupons['Y'] == 1].shape[0]/ bar_coupons.shape[0]
# Out:
# 0.41191845269210664

# %% [markdown]
# 3. Compare the acceptance rate between those who went to a bar 3 or fewer times a month to those who went more.

# %%
# acceptance rate for bar goers 4~8 times 
bar_coupons.loc[(bar_coupons['Y'] == 1) & (bar_coupons['Bar'] == "4~8")].shape[0]/ bar_coupons.loc[(bar_coupons['Bar'] == "4~8")].shape[0]
# Out:
# 0.7755102040816326

# %%
# acceptance rate for the bar goers never, less1, and 1~3
bar_coupons_3_and_fewer = bar_coupons.loc[(bar_coupons['Bar'] == "never") | (bar_coupons['Bar'] == "1~3") |(bar_coupons['Bar'] == "less1")]
bar_coupons_3_and_fewer.loc[(bar_coupons['Y'] == 1)].shape[0]/ bar_coupons_3_and_fewer.shape[0]
# Out:
# 0.37267441860465117

# %% [markdown]
# 4. Compare the acceptance rate between drivers who go to a bar more than once a month and are over the age of 25 to the all others.  Is there a difference?

# %%
# create new column Condition4, and assign Match for the folks who satisfy condition 4
bar_coupons.loc[((bar_coupons['Bar'] == "1~3") | (bar_coupons['Bar'] == "4~8")) & ((bar_coupons['age'] != "21") & (bar_coupons['age'] != "below21")), 'Condition4'] = 'Match'
# calculate acceptance rate
bar_coupons.loc[((bar_coupons['Condition4'] == "Match") & (bar_coupons['Y'] == 1))].shape[0]/ bar_coupons.loc[(bar_coupons['Condition4'] == "Match")].shape[0]
# result in 69% acceptance rate for folks who satisfy this condition, vs 41% acceptance as calculated above
# Out:
# 0.6890080428954424

# %% [markdown]
# 5. Use the same process to compare the acceptance rate between drivers who go to bars more than once a month and had passengers that were not a kid and had occupations other than farming, fishing, or forestry.

# %%
# create new column Condition5, and assign Match for the folks who satisfy condition 5
bar_coupons.loc[((bar_coupons['Bar'] != "never") & (bar_coupons['Bar'] != "less1") & (bar_coupons['passanger'] != "Kid(s)") & (bar_coupons['occupation'] != "Farming Fishing & Forestry")), 'Condition5'] = 'Match'
# calculate acceptance rate
bar_coupons.loc[((bar_coupons['Condition5'] == "Match") & (bar_coupons['Y'] == 1))].shape[0]/ bar_coupons.loc[(bar_coupons['Condition5'] == "Match")].shape[0]
# result in 71% acceptance rate for folks who satisfy this condition, vs 41% across everyone as calculated above
#bar_coupons.loc[((bar_coupons['Condition5'] == "Match"))]['occupation']#.str.contains('Farming')


#print(testtest)
# Out:
# 0.7094339622641509

# %% [markdown]
# 6. Compare the acceptance rates between those drivers who:
#
# - go to bars more than once a month, had passengers that were not a kid, and were not widowed *OR*
# - go to bars more than once a month and are under the age of 30 *OR*
# - go to cheap restaurants more than 4 times a month and income is less than 50K.

# %%
# Create column Condition6b that assign Match to: go to bars more than once a month, had passengers that were not a kid, and were not widowed 
bar_coupons.loc[(
   (((bar_coupons['Bar'] != "never") | (bar_coupons['Bar'] != "less1")) & (bar_coupons['passanger'] != "Kid(s)") 
   & (bar_coupons['maritalStatus'] != "Widowed"))), 
   'Condition6a'] = 'Match'

# calculate acceptance rate
Condition6a = bar_coupons.loc[((bar_coupons['Condition6a'] == "Match") & (bar_coupons['Y'] == 1))].shape[0]/ bar_coupons.loc[(bar_coupons['Condition6a'] == "Match")].shape[0]

print ("Condition6a: " + str(Condition6a) )

# 6a: result in 44% acceptance rate for folks who satisfy this condition, vs 41% across everyone as calculated above
# Out:
# Condition6a: 0.43537015276145713

# %%
# Create column Condition6b that assign Match to: go to bars more than once a month and are under the age of 30 
bar_coupons.loc[
   (((bar_coupons['Bar'] != "never") | (bar_coupons['Bar'] != "less1")) & ((bar_coupons['age'] == "21") | (bar_coupons['age'] == "26") | (bar_coupons['age'] == "below21") ) ), 
   'Condition6b'] = 'Match'

# calculate acceptance rate
Condition6b = bar_coupons.loc[((bar_coupons['Condition6b'] == "Match") & (bar_coupons['Y'] == 1))].shape[0]/ bar_coupons.loc[(bar_coupons['Condition6b'] == "Match")].shape[0]
print ("Condition6b: " + str(Condition6b) )

# 6b: result in 49% acceptance rate for folks who satisfy this condition, vs 41% across everyone as calculated above
# Out:
# Condition6b: 0.48817966903073284

# %%
# Create column Condition6c that assign Match to: go to cheap restaurants more than 4 times a month and income is less than 50K.
bar_coupons.loc[
  (( (bar_coupons['RestaurantLessThan20'] != "never") | (bar_coupons['RestaurantLessThan20'] != "1~3") | (bar_coupons['RestaurantLessThan20'] != "less1")) & 
     ((bar_coupons['income'] == "$12500 - $24999") | (bar_coupons['income'] == "$25000 - $37499") | (bar_coupons['income'] == "$37500 - $49999") | (bar_coupons['income'] == "Less than $12500") )),  

   'Condition6c'] = 'Match'

# calculate acceptance rate
Condition6c = bar_coupons.loc[((bar_coupons['Condition6c'] == "Match") & (bar_coupons['Y'] == 1))].shape[0]/ bar_coupons.loc[(bar_coupons['Condition6c'] == "Match")].shape[0]
print ("Condition6c: " + str(Condition6c) )

# 6c: result in 42% acceptance rate for folks who satisfy this condition, vs 41% across everyone as calculated above
# Out:
# Condition6c: 0.4227226202661208

# %% [markdown]
# 7.  Based on these observations, what do you hypothesize about drivers who accepted the bar coupons?

# %%
#Highest acceptance rate:
#Lowest acceptance rate:

# %% [markdown]
# Based on the sampled population/ dataset, we can hypothesize that drivers with following characteristics are more likely to accept coupons:
# *   Frequent bar goers (4~8) - 78% vs 37% for rest of observations
# *   Bar goers over the age of 25 (69%)
# *   Bar goers without kids as passengers, and not in the farming/ fishing/ forestry industry (71%)
# *   Bar goers without kids and not widowed have only a slightly higher acceptance rate (44%) then average (41%)
# *   Younger bar goers (<30 years) are more likely to accept (49%) then average, however not as much those over the age of 25 (69%), suggesting >=30 years old are much more likely to accept coupons
# *   Individuals with income less than 50K and eat in cheap restaurants >4 times a month are accepting coupons broadly in average across all samples population

# %% [markdown]
# ### Independent Investigation
#
# Using the bar coupon example as motivation, you are to explore one of the other coupon groups and try to determine the characteristics of passengers who accept the coupons.

# %% [markdown]
# In the next section I will explore acceptance rates for drivers who get coupons for low priced restaurants.

# %%
Rest20_coupons = data2.loc[data2['coupon'] == 'Restaurant(<20)'].copy()
print(type(Rest20_coupons))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
#data3['Y'] = data3['Y'].astype(object)
Rest20_coupons.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2653 entries, 22 to 12678
# Data columns (total 25 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   destination           2653 non-null   object
#  1   passanger             2653 non-null   object
#  2   weather               2653 non-null   object
#  3   temperature           2653 non-null   int64
#  4   time                  2653 non-null   object
#  5   coupon                2653 non-null   object
#  6   expiration            2653 non-null   object
#  7   gender                2653 non-null   object
#  8   age                   2653 non-null   object
#  9   maritalStatus         2653 non-null   object
#  10  has_children          2653 non-null   int64
#  11  education             2653 non-null   object
#  12  occupation            2653 non-null   object
#  13  income                2653 non-null   object
#  14  Bar                   2653 non-null   object
#  15  CoffeeHouse           2653 non-null   object
#  16  CarryAway             2653 non-null   object
#  17  RestaurantLessThan20  2653 non-null   object
#  18  Restaurant20To50      2653 non-null   object
#  19  toCoupon_GEQ5min      2653 non-null   int64
#  20  toCoupon_GEQ15min     2653 non-null   int64
#  21  toCoupon_GEQ25min     2653 non-null   int64
#  22  direction_same        2653 non-null   int64
#  23  direction_opp         2653 non-null   int64
#  24  Y                     2653 non-null   int64
# dtypes: int64(8), object(17)
# memory usage: 538.9+ KB

# %%
# 1. Plot multiple charts to understand the distribution for each category between accepting and not
# First filter for only categorical columns
categoric = Rest20_coupons.select_dtypes('object').columns
# Then create individual countplots for each categorical column, this time including a breakdown between Y/N.
plt.figure(figsize=(18, 100))
for i, col in enumerate(categoric):
   ax = plt.subplot(len(categoric), 1, i+1)
   sns.countplot(data=Rest20_coupons, x=col, ax=ax, hue = 'Y')

# %% [markdown]
# A quick scan of the graphs above show a few interesting areas to explore further:

# %%
# 1. Plot multiple charts to understand the distribution for each category between accepting and not
# First filter for only categorical columns
#categoric = Rest20_coupons.select_dtypes('object').columns
# Then create individual countplots for each categorical column, this time including a breakdown between Y/N.
#plt.figure(figsize=(18, 100))
#for i, col in enumerate(categoric):
#   ax = plt.subplot(len(categoric), 1, i+1)
   #sns.countplot(data=Rest20_coupons, x=col, ax=ax, hue = 'Y')
   #Rest20_coupons[col].plot(ax=ax)
   #Rest20_coupons.groupby(col)['Y'].value_counts(normalize=True).mul(100).rename('percent').reset_index().plot(ax=ax,x=col,kind='bar',stacked = True)
   #Rest20_coupons.groupby(col)['Y'].value_counts(normalize=True).mul(100).rename('percent').plot(ax=ax,x=col,kind='bar',stacked = True)
   #print(Rest20_coupons.groupby(col)['Y'].value_counts(normalize=True).mul(100).round(0).rename('percent').reset_index())
   #pipe((sns.catplot,'data'), x=x,ax=ax,hue="Y",kind='bar')
   #tochart=Rest20_coupons.groupby(col)['Y'].value_counts(normalize=True).mul(100).round(0)#.reset_index()
   #sns.catplot(data=tochart, x=col, ax=ax, type = 'hist')
   #sns.barplot(data=Rest20_coupons, x=col, ax=ax, hue = 'Y')
   #x,y = col,"Y"
#   Rest20_coupons.groupby(col)['Y'].value_counts(normalize=True).mul(100).rename('percent').reset_index().pipe((sns.catplot,'data'), x=x,ax=ax,hue="Y",kind='bar')
     
   # link: https://stackoverflow.com/questions/34615854/seaborn-countplot-with-normalized-y-axis-per-group

# %%
#Calculate acceptance rate across all the subsample
Rest20_coupons['Y'].value_counts(normalize=True).mul(100).round(0)
#Answer is 71%
# Out:
# 1    71.0
# 0    29.0
# Name: Y, dtype: float64

# %%
#Calculate % acceptance rate across all categories to identify outliers 
categoric = Rest20_coupons.select_dtypes('object').columns
for i, col in enumerate(categoric):
   print(Rest20_coupons.groupby(col)['Y'].mean())
# Out:
# destination
# Home               0.557652
# No Urgent Place    0.794226
# Work               0.587591
# Name: Y, dtype: float64
# passanger
# Alone        0.640876
# Friend(s)    0.803549
# Kid(s)       0.710843
# Partner      0.783673
# Name: Y, dtype: float64
# weather
# Rainy    0.393750
# Snowy    0.495798
# Sunny    0.768258
# Name: Y, dtype: float64
# time
# 10AM    0.717770
# 10PM    0.507901
# 2PM     0.813636
# 6PM     0.826573
# 7AM     0.587591
# Name: Y, dtype: float64
# coupon
# Restaurant(<20)    0.709009
# Name: Y, dtype: float64
# expiration
# 1d    0.835913
# 2h    0.588538
# Name: Y, dtype: float64
# gender
# Female    0.698295
# Male      0.720092
# Name: Y, dtype: float64
# age
# 21         0.738095
# 26         0.741874
# 31         0.708134
# 36         0.647687
# 41         0.716049
# 46         0.750000
# 50plus     0.639474
# below21    0.737288
# Name: Y, dtype: float64
# maritalStatus
# Divorced             0.627119
# Married partner      0.692453
# Single               0.733135
# Unmarried partner    0.725225
# Widowed              0.521739
# Name: Y, dtype: float64
# education
# Associates degree                         0.659091
# Bachelors degree                          0.731293
# Graduate degree (Masters or Doctorate)    0.615572
# High School Graduate                      0.715054
# Some High School                          0.722222
# Some college - no degree                  0.739316
# Name: Y, dtype: float64
# occupation
# Architecture & Engineering                   0.794872
# Arts Design Entertainment Sports & Media     0.677419
# Building & Grounds Cleaning & Maintenance    0.400000
# Business & Financial                         0.658333
# Community & Social Services                  0.673913
# Computer & Mathematical                      0.707904
# Construction & Extraction                    0.885714
# Education&Training&Library                   0.673367
# Farming Fishing & Forestry                   0.571429
# Food Preparation & Serving Related           0.696970
# Healthcare Practitioners & Technical         0.777778
# Healthcare Support                           0.735849
# Installation Maintenance & Repair            0.703704
# Legal                                        0.591837
# Life Physical Social Science                 0.833333
# Management                                   0.731429
# Office & Administrative Support              0.772727
# Personal Care & Service                      0.558824
# Production Occupations                       0.800000
# Protective Service                           0.894737
# Retired                                      0.580952
# Sales & Related                              0.798283
# Student                                      0.714724
# Transportation & Material Moving             0.739130
# Unemployed                                   0.670025
# Name: Y, dtype: float64
# income
# $100000 or More     0.718157
# $12500 - $24999     0.679045
# $25000 - $37499     0.767059
# $37500 - $49999     0.682927
# $50000 - $62499     0.773414
# $62500 - $74999     0.695187
# $75000 - $87499     0.688525
# $87500 - $99999     0.576087
# Less than $12500    0.719298
# Name: Y, dtype: float64
# Bar
# 1~3      0.740187
# 4~8      0.750000
# gt8      0.640000
# less1    0.689424
# never    0.703008
# Name: Y, dtype: float64
# CoffeeHouse
# 1~3      0.764622
# 4~8      0.723757
# gt8      0.629032
# less1    0.700000
# never    0.680064
# Name: Y, dtype: float64
# CarryAway
# 1~3      0.740102
# 4~8      0.717105
# gt8      0.708824
# less1    0.605670
# never    0.785714
# Name: Y, dtype: float64
# RestaurantLessThan20
# 1~3      0.704607
# 4~8      0.719276
# gt8      0.760417
# less1    0.676471
# never    0.627907
# Name: Y, dtype: float64
# Restaurant20To50
# 1~3      0.754745
# 4~8      0.698795
# gt8      0.694915
# less1    0.693925
# never    0.688453
# Name: Y, dtype: float64

# %%
# Show the number of categories in each alongside percentages 
categoric = Rest20_coupons.select_dtypes('object').columns
for i, col in enumerate(categoric):
   print(str (Rest20_coupons.groupby(col)['Y'].value_counts()) + " " + str (Rest20_coupons.groupby(col)['Y'].mean()) )
# Out:
# destination      Y
# Home             1     266
#                  0     211
# No Urgent Place  1    1293
#                  0     335
# Work             1     322
#                  0     226
# Name: Y, dtype: int64 destination
# Home               0.557652
# No Urgent Place    0.794226
# Work               0.587591
# Name: Y, dtype: float64
# passanger  Y
# Alone      1    878
#            0    492
# Friend(s)  1    634
#            0    155
# Kid(s)     1    177
#            0     72
# Partner    1    192
#            0     53
# Name: Y, dtype: int64 passanger
# Alone        0.640876
# Friend(s)    0.803549
# Kid(s)       0.710843
# Partner      0.783673
# Name: Y, dtype: float64
# weather  Y
# Rainy    0      97
#          1      63
# Snowy    0     180
#          1     177
# Sunny    1    1641
#          0     495
# Name: Y, dtype: int64 weather
# Rainy    0.393750
# Snowy    0.495798
# Sunny    0.768258
# Name: Y, dtype: float64
# time  Y
# 10AM  1    206
#       0     81
# 10PM  1    225
#       0    218
# 2PM   1    537
#       0    123
# 6PM   1    591
#       0    124
# 7AM   1    322
#       0    226
# Name: Y, dtype: int64 time
# 10AM    0.717770
# 10PM    0.507901
# 2PM     0.813636
# 6PM     0.826573
# 7AM     0.587591
# Name: Y, dtype: float64
# coupon           Y
# Restaurant(<20)  1    1881
#                  0     772
# Name: Y, dtype: int64 coupon
# Restaurant(<20)    0.709009
# Name: Y, dtype: float64
# expiration  Y
# 1d          1    1080
#             0     212
# 2h          1     801
#             0     560
# Name: Y, dtype: int64 expiration
# 1d    0.835913
# 2h    0.588538
# Name: Y, dtype: float64
# gender  Y
# Female  1    942
#         0    407
# Male    1    939
#         0    365
# Name: Y, dtype: int64 gender
# Female    0.698295
# Male      0.720092
# Name: Y, dtype: float64
# age      Y
# 21       1    403
#          0    143
# 26       1    388
#          0    135
# 31       1    296
#          0    122
# 36       1    182
#          0     99
# 41       1    174
#          0     69
# 46       1    108
#          0     36
# 50plus   1    243
#          0    137
# below21  1     87
#          0     31
# Name: Y, dtype: int64 age
# 21         0.738095
# 26         0.741874
# 31         0.708134
# 36         0.647687
# 41         0.716049
# 46         0.750000
# 50plus     0.639474
# below21    0.737288
# Name: Y, dtype: float64
# maritalStatus      Y
# Divorced           1     74
#                    0     44
# Married partner    1    734
#                    0    326
# Single             1    739
#                    0    269
# Unmarried partner  1    322
#                    0    122
# Widowed            1     12
#                    0     11
# Name: Y, dtype: int64 maritalStatus
# Divorced             0.627119
# Married partner      0.692453
# Single               0.733135
# Unmarried partner    0.725225
# Widowed              0.521739
# Name: Y, dtype: float64
# education                               Y
# Associates degree                       1    145
#                                         0     75
# Bachelors degree                        1    645
#                                         0    237
# Graduate degree (Masters or Doctorate)  1    253
#                                         0    158
# High School Graduate                    1    133
#                                         0     53
# Some High School                        1     13
#                                         0      5
# Some college - no degree                1    692
#                                         0    244
# Name: Y, dtype: int64 education
# Associates degree                         0.659091
# Bachelors degree                          0.731293
# Graduate degree (Masters or Doctorate)    0.615572
# High School Graduate                      0.715054
# Some High School                          0.722222
# Some college - no degree                  0.739316
# Name: Y, dtype: float64
# occupation                                 Y
# Architecture & Engineering                 1     31
#                                            0      8
# Arts Design Entertainment Sports & Media   1     84
#                                            0     40
# Building & Grounds Cleaning & Maintenance  0      6
#                                            1      4
# Business & Financial                       1     79
#                                            0     41
# Community & Social Services                1     31
#                                            0     15
# Computer & Mathematical                    1    206
#                                            0     85
# Construction & Extraction                  1     31
#                                            0      4
# Education&Training&Library                 1    134
#                                            0     65
# Farming Fishing & Forestry                 1      4
#                                            0      3
# Food Preparation & Serving Related         1     46
#                                            0     20
# Healthcare Practitioners & Technical       1     35
#                                            0     10
# Healthcare Support                         1     39
#                                            0     14
# Installation Maintenance & Repair          1     19
#                                            0      8
# Legal                                      1     29
#                                            0     20
# Life Physical Social Science               1     30
#                                            0      6
# Management                                 1    128
#                                            0     47
# Office & Administrative Support            1    102
#                                            0     30
# Personal Care & Service                    1     19
#                                            0     15
# Production Occupations                     1     16
#                                            0      4
# Protective Service                         1     34
#                                            0      4
# Retired                                    1     61
#                                            0     44
# Sales & Related                            1    186
#                                            0     47
# Student                                    1    233
#                                            0     93
# Transportation & Material Moving           1     34
#                                            0     12
# Unemployed                                 1    266
#                                            0    131
# Name: Y, dtype: int64 occupation
# Architecture & Engineering                   0.794872
# Arts Design Entertainment Sports & Media     0.677419
# Building & Grounds Cleaning & Maintenance    0.400000
# Business & Financial                         0.658333
# Community & Social Services                  0.673913
# Computer & Mathematical                      0.707904
# Construction & Extraction                    0.885714
# Education&Training&Library                   0.673367
# Farming Fishing & Forestry                   0.571429
# Food Preparation & Serving Related           0.696970
# Healthcare Practitioners & Technical         0.777778
# Healthcare Support                           0.735849
# Installation Maintenance & Repair            0.703704
# Legal                                        0.591837
# Life Physical Social Science                 0.833333
# Management                                   0.731429
# Office & Administrative Support              0.772727
# Personal Care & Service                      0.558824
# Production Occupations                       0.800000
# Protective Service                           0.894737
# Retired                                      0.580952
# Sales & Related                              0.798283
# Student                                      0.714724
# Transportation & Material Moving             0.739130
# Unemployed                                   0.670025
# Name: Y, dtype: float64
# income            Y
# $100000 or More   1    265
#                   0    104
# $12500 - $24999   1    256
#                   0    121
# $25000 - $37499   1    326
#                   0     99
# $37500 - $49999   1    252
#                   0    117
# $50000 - $62499   1    256
#                   0     75
# $62500 - $74999   1    130
#                   0     57
# $75000 - $87499   1    126
#                   0     57
# $87500 - $99999   1    106
#                   0     78
# Less than $12500  1    164
#                   0     64
# Name: Y, dtype: int64 income
# $100000 or More     0.718157
# $12500 - $24999     0.679045
# $25000 - $37499     0.767059
# $37500 - $49999     0.682927
# $50000 - $62499     0.773414
# $62500 - $74999     0.695187
# $75000 - $87499     0.688525
# $87500 - $99999     0.576087
# Less than $12500    0.719298
# Name: Y, dtype: float64
# Bar    Y
# 1~3    1    396
#        0    139
# 4~8    1    174
#        0     58
# gt8    1     48
#        0     27
# less1  1    515
#        0    232
# never  1    748
#        0    316
# Name: Y, dtype: int64 Bar
# 1~3      0.740187
# 4~8      0.750000
# gt8      0.640000
# less1    0.689424
# never    0.703008
# Name: Y, dtype: float64
# CoffeeHouse  Y
# 1~3          1    536
#              0    165
# 4~8          1    262
#              0    100
# gt8          1    156
#              0     92
# less1        1    504
#              0    216
# never        1    423
#              0    199
# Name: Y, dtype: int64 CoffeeHouse
# 1~3      0.764622
# 4~8      0.723757
# gt8      0.629032
# less1    0.700000
# never    0.680064
# Name: Y, dtype: float64
# CarryAway  Y
# 1~3        1    729
#            0    256
# 4~8        1    654
#            0    258
# gt8        1    241
#            0     99
# less1      1    235
#            0    153
# never      1     22
#            0      6
# Name: Y, dtype: int64 CarryAway
# 1~3      0.740102
# 4~8      0.717105
# gt8      0.708824
# less1    0.605670
# never    0.785714
# Name: Y, dtype: float64
# RestaurantLessThan20  Y
# 1~3                   1    780
#                       0    327
# 4~8                   1    556
#                       0    217
# gt8                   1    219
#                       0     69
# less1                 1    299
#                       0    143
# never                 1     27
#                       0     16
# Name: Y, dtype: int64 RestaurantLessThan20
# 1~3      0.704607
# 4~8      0.719276
# gt8      0.760417
# less1    0.676471
# never    0.627907
# Name: Y, dtype: float64
# Restaurant20To50  Y
# 1~3               1    517
#                   0    168
# 4~8               1    116
#                   0     50
# gt8               1     41
#                   0     18
# less1             1    891
#                   0    393
# never             1    316
#                   0    143
# Name: Y, dtype: int64 Restaurant20To50
# 1~3      0.754745
# 4~8      0.698795
# gt8      0.694915
# less1    0.693925
# never    0.688453
# Name: Y, dtype: float64

# %% [markdown]
# Based on the observations above, drivers who are most likely to accept coupons have the attributes below. We will further examine more some of these dimensions to get more detailed insights.
# *   Destination: No urgent place
# *   passanger: Friends(s)
# *   weather: Sunny
# *   Time: 2PM, 6 PM
# *   Expiration: 1d
# *   maritalStats: Single + Unmarried partner
# *   occupation: Protective Service, Construction & Extraction
# *   CarryAway: never

# %%
#Explore acceptance rate depending on frequency of restaurant visits, 
#Number of times that he/she eats at a restaurant with average expense less than \$20 per person: 0, less than 1, 1 to 3, 4 to 8 or greater than 8
x,y = 'RestaurantLessThan20', 'Y' 


qchart = Rest20_coupons.groupby(x)[y].value_counts(normalize=True).mul(100).round(0).rename('percent').reset_index()

g = sns.catplot(x=x,y='percent',hue=y,kind='bar',data=qchart)
g.fig.suptitle('  Acceptance from lower priced restaurants goers')
g.ax.set_ylim(0,100)
 
for p in g.ax.patches:
    txt = str(p.get_height().round(2)) + '%'
    txt_x = p.get_x() 
    txt_y = p.get_height()
    g.ax.text(txt_x,txt_y,txt)

# Takeaway: Althouth gt8 have the largest percentage of acceptance (76%), its interesting that the acceptance for never is 
# still quite high, potentially indicating an opoprtunity to attract new customers

# %%
#Lets examine the acceptance for drivers to tend to go to more expensive restaurants
x,y = 'Restaurant20To50', 'Y' 

qchart = Rest20_coupons.groupby(x)[y].value_counts(normalize=True).mul(100).round(0).rename('percent').reset_index()
 
g = sns.catplot(x=x,y='percent',hue=y,kind='bar',data=qchart)
g.fig.suptitle('. Acceptance from higher priced restaurants goers')
g.ax.set_ylim(0,100)
 
for p in g.ax.patches:
    txt = str(p.get_height().round(2)) + '%'
    txt_x = p.get_x() 
    txt_y = p.get_height()
    g.ax.text(txt_x,txt_y,txt)

# Takeaway: Drivers who ocasionally (1~3 per month) visit more expensive restaurants, are also open to accept coupons from lower priced restaurants.

# %%
#Lets explore the acceptance rate of the drivers who are most likely to accept in the individual categories
#Destination: No urgent place
#passanger: Friends(s)
#weather: Sunny
#Time: 2PM, 6 PM
#Expiration: 1d
#maritalStats: Single + Unmarried partner
#occupation: Protective Service, Construction & Extraction

# Create column MostLikely that assign Match to drivers who satisfy the condition above

r20 = Rest20_coupons.copy()
r20.loc[((r20.destination == "No Urgent Place")& (r20['passanger'] == "Friend(s)")& (r20['weather'] == 'Sunny')), 'MostLikely1'] = "Match"

print(r20[r20['MostLikely1'] == "Match"].groupby('MostLikely1')['Y'].mean())

#MostLikely = r20.loc[((r20['MostLikely'] == "Match") & (r20['Y'] == 1))].shape[0]/ r20.loc[(r20['MostLikely'] == "Match")].shape[0]
#print ("MostLikely: " + str(MostLikely) )


#[DEPRECATED:]
#print(r20.loc[((r20['Y'] == 1) & (r20["MostLikely"] == "Match"))].value_counts(normalize=True).mul(100).round(0))
# calculate acceptance rate

# result in 80% acceptance rate for folks who satisfy this condition
# Out:
# MostLikely1
# Match    0.802878
# Name: Y, dtype: float64

# %%
print(r20[r20['MostLikely1'] == "Match"].info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 695 entries, 29 to 12662
# Data columns (total 26 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   destination           695 non-null    object
#  1   passanger             695 non-null    object
#  2   weather               695 non-null    object
#  3   temperature           695 non-null    int64
#  4   time                  695 non-null    object
#  5   coupon                695 non-null    object
#  6   expiration            695 non-null    object
#  7   gender                695 non-null    object
#  8   age                   695 non-null    object
#  9   maritalStatus         695 non-null    object
#  10  has_children          695 non-null    int64
#  11  education             695 non-null    object
#  12  occupation            695 non-null    object
#  13  income                695 non-null    object
#  14  Bar                   695 non-null    object
#  15  CoffeeHouse           695 non-null    object
#  16  CarryAway             695 non-null    object
#  17  RestaurantLessThan20  695 non-null    object
#  18  Restaurant20To50      695 non-null    object
#  19  toCoupon_GEQ5min      695 non-null    int64
#  20  toCoupon_GEQ15min     695 non-null    int64
#  21  toCoupon_GEQ25min     695 non-null    int64
#  22  direction_same        695 non-null    int64
#  23  direction_opp         695 non-null    int64
#  24  Y                     695 non-null    int64
#  25  MostLikely1           695 non-null    object
# dtypes: int64(8), object(18)
# memory usage: 146.6+ KB
# None

# %%
#Lets explore the acceptance rate of the drivers who are most likely to accept in the individual categories
#Destination: No urgent place
#passanger: Friends(s)
#weather: Sunny
#Time: 2PM, 6 PM
#Expiration: 1d
#maritalStats: Single + Unmarried partner
#occupation: Protective Service, Construction & Extraction

# Create column MostLikely that assign Match to drivers who satisfy the condition above

r20 = Rest20_coupons.copy()
r20.loc[(((r20.time == "2PM") | (r20.time == "6PM"))& (r20['expiration'] == "1d") & ((r20.maritalStatus == 'Single')|(r20.maritalStatus == 'Unmarried partner') )
 & ((r20.occupation == 'Protective Service')|(r20.occupation == 'Construction & Extraction') ) ), 'MostLikely2'] = "Match"
r20[r20['MostLikely2'] == "Match"].info()
#print(r20.groupby('MostLikely2')['Y'].mean())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6 entries, 2982 to 11584
# Data columns (total 26 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   destination           6 non-null      object
#  1   passanger             6 non-null      object
#  2   weather               6 non-null      object
#  3   temperature           6 non-null      int64
#  4   time                  6 non-null      object
#  5   coupon                6 non-null      object
#  6   expiration            6 non-null      object
#  7   gender                6 non-null      object
#  8   age                   6 non-null      object
#  9   maritalStatus         6 non-null      object
#  10  has_children          6 non-null      int64
#  11  education             6 non-null      object
#  12  occupation            6 non-null      object
#  13  income                6 non-null      object
#  14  Bar                   6 non-null      object
#  15  CoffeeHouse           6 non-null      object
#  16  CarryAway             6 non-null      object
#  17  RestaurantLessThan20  6 non-null      object
#  18  Restaurant20To50      6 non-null      object
#  19  toCoupon_GEQ5min      6 non-null      int64
#  20  toCoupon_GEQ15min     6 non-null      int64
#  21  toCoupon_GEQ25min     6 non-null      int64
#  22  direction_same        6 non-null      int64
#  23  direction_opp         6 non-null      int64
#  24  Y                     6 non-null      int64
#  25  MostLikely2           6 non-null      object
# dtypes: int64(8), object(18)
# memory usage: 1.3+ KB

# %% [markdown]
# Applying these criteria for time, expiration, marital status and occupation  resulted in 100% acceptance rate, however the number observations is only 6.

# %%
#Lets explore the attributes of drivers who have the lowest coupon acceptance rate.
# the acceptance for drivers to tend to go to more expensive restaurants
x,y = 'time', 'Y' 

qchart = Rest20_coupons.groupby(x)[y].value_counts(normalize=True).mul(100).round(0).rename('percent').reset_index()
 
g = sns.catplot(x=x,y='percent',hue=y,kind='bar',data=qchart)
g.fig.suptitle(' Acceptance based on time of coupon issuance', size = 10)
g.ax.set_ylim(0,100)
 
for p in g.ax.patches:
    txt = str(p.get_height().round(2)) + '%'
    txt_x = p.get_x() 
    txt_y = p.get_height()
    g.ax.text(txt_x,txt_y,txt)

# Takeaway: The lowest acceptance rate is for coupons issued at 7 am and 10 pm, which intuitively makes sense

# %%
#Lets explore the attributes of drivers who have the lowest coupon acceptance rate.
# the acceptance for drivers to tend to go to more expensive restaurants
x,y = 'weather', 'Y' 

qchart = Rest20_coupons.groupby(x)[y].value_counts(normalize=True).mul(100).round(0).rename('percent').reset_index()
 
g = sns.catplot(x=x,y='percent',hue=y,kind='bar',data=qchart)
g.fig.suptitle(' Acceptance based on weather', size = 10)
g.ax.set_ylim(0,100)
 
for p in g.ax.patches:
    txt = str(p.get_height().round(2)) + '%'
    txt_x = p.get_x() 
    txt_y = p.get_height()
    g.ax.text(txt_x,txt_y,txt)

# Takeaway: Interestingly weather has a huge impact on whether a coupon is accepted, the lowest rate being in Rainy weather at 39%, and highest during Sunny days at 77%.
